# %%
#open the data
#process the first string and get its gc content 
first count the number of g from the first string
count the number of c from the first string
calculate the dna length of the first string
compute the gc content by using the formula no. of g+no. of c/dna length*100
do the same for second string and compare the gc content of both the strings 
name the string which has higher gc content as best gc and use it for the next step
do the same step for all the dna strings in the given data to check the gc content till you get the string with the highest gc content

# %%
data=open("")

# %%
best_gc=0.0
best_id=""
current_id=""
dna_data={}

# %%
count_g=data.count('G')
count_c=data.count('C')
dna_length=len(data)
gc_content=(count_g+count_c)/dna_length*100

# %%
for line in data:
    if line.startswith(">"):
        current_id=line[1:]
        dna_data[current_id]=""
    else:
        dna_data[current_id]

for seq_id,seq in dna_data:
    count_g=dna_data.count('G')
    count_c=dna_data.count('C')
    dna_length=len(dna_data)
    gc_content=(count_g+count_c)/dna_length*100
    if gc_content>best_gc
       best_gc=gc_content
       best_id=seq_id
    print(best_gc)
    print(best_id)

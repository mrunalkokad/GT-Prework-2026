# %%
read string s
read integers a,b,c,d
slice first_part from a to b
slice second_part from c to d
print first_part and second_part

# %%
s="HumptyDumptysatonawallHumptyDumptyhadagreatfallAlltheKingshorsesandalltheKingsmenCouldntputHumptyDumptyinhisplaceagain"
a=22
b=27
c=97
d=102
first_part=s[a:b+1]
second_part=s[c:d+1]
print(first_part,second_part)
# Out:
# Humpty Dumpty

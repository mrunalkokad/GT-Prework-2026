# %%
#Printing
a= input().strip()
b= input().strip()
separator= input().strip()
print(a+separator+b)
# Out:
#  Hello
#  World
#  @
# Hello@World

# %%
#Multiprinting
a= input().strip()
n=int(input().strip())
print(a*n)
# Out:
#  Hello
#  5
# HelloHelloHelloHelloHello

# %%
#Int Str
a= input().strip()
b= input().strip()
c= input().strip()
print(a*int(a)+c+b*int(b))
# Out:
#  6
#  4
#  &
# 666666&4444

# %%
#Taking Input
s=input()
print(s)

n=int(input())
print(n)

f=float(input())
print(int)
